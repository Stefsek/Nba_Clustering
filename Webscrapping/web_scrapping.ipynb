# %%
#import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
#beautiful soup
url = 'https://www.basketball-reference.com/leagues/NBA_{}_per_game.html'.format(2021)
   
r = requests.get(url)
r_html = r.text
soup = BeautifulSoup(r_html,'html.parser')

# %%
#extracting data
#this process was repeated for all years from 1980 till 2021 so we refreshed the website every time we wanted different date
table=soup.find_all(class_="full_table")
    
""" Extracting List of column names"""
head=soup.find(class_="thead")
column_names_raw=[head.text for item in head][0]
column_names_polished=column_names_raw.replace("\n",",").split(",")[2:-1]
print(column_names_polished)
['Player',
 'Pos',
 'Age',
 'Tm',
 'G',
 'GS',
 'MP',
 'FG',
 'FGA',
 'FG%',
 '3P',
 '3PA',
 '3P%',
 '2P',
 '2PA',
 '2P%',
 'eFG%',
 'FT',
 'FTA',
 'FT%',
 'ORB',
 'DRB',
 'TRB',
 'AST',
 'STL',
 'BLK',
 'TOV',
 'PF',
 'PTS']
# Out:
# ['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']
# ['Player',
#  'Pos',
#  'Age',
#  'Tm',
#  'G',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  '2P',
#  '2PA',
#  '2P%',
#  'eFG%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS']

# %%
#Extracting full list of player_data

players=[]
    
for i in range(len(table)):
    player_=[]
    for td in table[i].find_all("td"):
        player_.append(td.text)
    
        players.append(player_)
df=pd.DataFrame(players, columns=column_names_polished).set_index("Player")
#cleaning the player's name from occasional special characters
df.index=df.index.str.replace('*', '')
# Out:
# C:\Users\schek\AppData\Local\Temp/ipykernel_21844/501480424.py:12: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.index=df.index.str.replace('*', '')

# %%
df
# Out:
#                  Pos Age   Tm   G  GS    MP   FG  FGA   FG%   3P  3PA   3P%  \
# Player
# Precious Achiuwa  PF  21  MIA  61   4  12.1  2.0  3.7  .544  0.0  0.0  .000
# Precious Achiuwa  PF  21  MIA  61   4  12.1  2.0  3.7  .544  0.0  0.0  .000
# Precious Achiuwa  PF  21  MIA  61   4  12.1  2.0  3.7  .544  0.0  0.0  .000
# Precious Achiuwa  PF  21  MIA  61   4  12.1  2.0  3.7  .544  0.0  0.0  .000
# Precious Achiuwa  PF  21  MIA  61   4  12.1  2.0  3.7  .544  0.0  0.0  .000
# ...               ..  ..  ...  ..  ..   ...  ...  ...   ...  ...  ...   ...
# Ivica Zubac        C  23  LAC  72  33  22.3  3.6  5.5  .652  0.0  0.1  .250
# Ivica Zubac        C  23  LAC  72  33  22.3  3.6  5.5  .652  0.0  0.1  .250
# Ivica Zubac        C  23  LAC  72  33  22.3  3.6  5.5  .652  0.0  0.1  .250
# Ivica Zubac        C  23  LAC  72  33  22.3  3.6  5.5  .652  0.0  0.1  .250
# Ivica Zubac        C  23  LAC  72  33  22.3  3.6  5.5  .652  0.0  0.1  .250
#
# ...

# %%
#drop duplicates
data = df.drop_duplicates()

# %%
data
# Out:
#                      Pos Age   Tm   G  GS    MP   FG   FGA   FG%   3P  3PA  \
# Player
# Precious Achiuwa      PF  21  MIA  61   4  12.1  2.0   3.7  .544  0.0  0.0
# Jaylen Adams          PG  24  MIL   7   0   2.6  0.1   1.1  .125  0.0  0.3
# Steven Adams           C  27  NOP  58  58  27.7  3.3   5.3  .614  0.0  0.1
# Bam Adebayo            C  23  MIA  64  64  33.5  7.1  12.5  .570  0.0  0.1
# LaMarcus Aldridge      C  35  TOT  26  23  25.9  5.4  11.4  .473  1.2  3.1
# ...                  ...  ..  ...  ..  ..   ...  ...   ...   ...  ...  ...
# Delon Wright       SG-PG  28  TOT  63  39  27.7  3.8   8.2  .463  1.0  2.7
# Thaddeus Young        PF  32  CHI  68  23  24.3  5.4   9.7  .559  0.2  0.7
# Trae Young            PG  22  ATL  63  63  33.7  7.7  17.7  .438  2.2  6.3
# Cody Zeller            C  28  CHO  48  21  20.9  3.8   6.8  .559  0.1  0.6
# Ivica Zubac            C  23  LAC  72  33  22.3  3.6   5.5  .652  0.0  0.1
#
# ...

# %%
data['name'] = data.index
# Out:
# C:\Users\schek\AppData\Local\Temp/ipykernel_9884/3955373534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['name'] = data.index

# %%
#data to csv
data.to_csv('nba2021.csv')

# %%
#read all csv's we stored
df1 = pd.read_csv('nba1980.csv')
df2 = pd.read_csv('nba1981.csv')
df3 = pd.read_csv('nba1982.csv')
df4 = pd.read_csv('nba1983.csv')
df5 = pd.read_csv('nba1984.csv')
df6 = pd.read_csv('nba1985.csv')
df7 = pd.read_csv('nba1986.csv')
df8 = pd.read_csv('nba1987.csv')
df9 = pd.read_csv('nba1988.csv')
df10 = pd.read_csv('nba1989.csv')
df11= pd.read_csv('nba1990.csv')
df12= pd.read_csv('nba1991.csv')
df13= pd.read_csv('nba1992.csv')
df14= pd.read_csv('nba1993.csv')
df15= pd.read_csv('nba1994.csv')
df16= pd.read_csv('nba1995.csv')
df17= pd.read_csv('nba1996.csv')
df18= pd.read_csv('nba1997.csv')
df19= pd.read_csv('nba1998.csv')
df20= pd.read_csv('nba1999.csv')
df21= pd.read_csv('nba2000.csv')
df22= pd.read_csv('nba2001.csv')
df23= pd.read_csv('nba2002.csv')
df24= pd.read_csv('nba2003.csv')
df25= pd.read_csv('nba2004.csv')
df26= pd.read_csv('nba2005.csv')
df27= pd.read_csv('nba2006.csv')
df28= pd.read_csv('nba2007.csv')
df29= pd.read_csv('nba2008.csv')
df30= pd.read_csv('nba2009.csv')
df31= pd.read_csv('nba2010.csv')
df32= pd.read_csv('nba2011.csv')
df33= pd.read_csv('nba2012.csv')
df34= pd.read_csv('nba2013.csv')
df35= pd.read_csv('nba2014.csv')
df36= pd.read_csv('nba2015.csv')
df37= pd.read_csv('nba2016.csv')
df38= pd.read_csv('nba2017.csv')
df39= pd.read_csv('nba2018.csv')
df40= pd.read_csv('nba2019.csv')
df41= pd.read_csv('nba2020.csv')
df42= pd.read_csv('nba2021.csv')

# %%
#frames and concat
frames = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30,
         df31,df32,df33,df34,df35,df36,df37,df38,df39,df40,df41]

# %%
nba = pd.concat(frames)

# %%
#save to csv
nba.to_csv('nba.csv')

# %%
nba
# Out:
#                   Player Pos  Age   Tm   G    GS    MP    FG   FGA    FG%  \
# 0    Kareem Abdul-Jabbar   C   32  LAL  82   NaN  38.3  10.2  16.9  0.604
# 1          Tom Abernethy  PF   25  GSW  67   NaN  18.2   2.3   4.7  0.481
# 2            Alvan Adams   C   25  PHO  75   NaN  28.9   6.2  11.7  0.531
# 3         Tiny Archibald  PG   31  BOS  80  80.0  35.8   4.8   9.9  0.482
# 4          Dennis Awtrey   C   31  CHI  26   NaN  21.5   1.0   2.3  0.450
# ..                   ...  ..  ...  ...  ..   ...   ...   ...   ...    ...
# 524           Trae Young  PG   21  ATL  60  60.0  35.3   9.1  20.8  0.437
# 525          Cody Zeller   C   27  CHO  58  39.0  23.1   4.3   8.3  0.524
# 526         Tyler Zeller   C   30  SAS   2   0.0   2.0   0.5   2.0  0.250
# 527           Ante Žižić   C   23  CLE  22   0.0  10.0   1.9   3.3  0.569
# 528          Ivica Zubac   C   22  LAC  72  70.0  18.4   3.3   5.3  0.613
#
#       3P  3PA    3P%    2P   2PA    2P%   eFG%   FT  FTA    FT%  ORB  DRB  \
# ...

# %%
#drop age column
nba=nba.drop(columns=['Age'])

# %%
nba
# Out:
#                   Player Pos   Tm   G    GS    MP    FG   FGA    FG%   3P  \
# 0    Kareem Abdul-Jabbar   C  LAL  82   NaN  38.3  10.2  16.9  0.604  0.0
# 1          Tom Abernethy  PF  GSW  67   NaN  18.2   2.3   4.7  0.481  0.0
# 2            Alvan Adams   C  PHO  75   NaN  28.9   6.2  11.7  0.531  0.0
# 3         Tiny Archibald  PG  BOS  80  80.0  35.8   4.8   9.9  0.482  0.1
# 4          Dennis Awtrey   C  CHI  26   NaN  21.5   1.0   2.3  0.450  0.0
# ..                   ...  ..  ...  ..   ...   ...   ...   ...    ...  ...
# 524           Trae Young  PG  ATL  60  60.0  35.3   9.1  20.8  0.437  3.4
# 525          Cody Zeller   C  CHO  58  39.0  23.1   4.3   8.3  0.524  0.3
# 526         Tyler Zeller   C  SAS   2   0.0   2.0   0.5   2.0  0.250  0.0
# 527           Ante Žižić   C  CLE  22   0.0  10.0   1.9   3.3  0.569  0.0
# 528          Ivica Zubac   C  LAC  72  70.0  18.4   3.3   5.3  0.613  0.0
#
#      3PA    3P%    2P   2PA    2P%   eFG%   FT  FTA    FT%  ORB  DRB   TRB  \
# ...
